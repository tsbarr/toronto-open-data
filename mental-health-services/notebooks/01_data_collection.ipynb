# %%
import sys
sys.path.append('../..')

from common.toronto_api import TorontoOpenDataAPI

import pandas as pd
import geojson
from datetime import datetime

# %%
# Initialize API client
client = TorontoOpenDataAPI()

# %% [markdown]
# ---
#
# ## Wellbeing Youth
#
# ### Mental Health

# %%
# Get package metadata using dataset id
package = client.get_package("wellbeing-youth-mental-health")
# Check resources in package
# client.show_resources_info(package)

# %%
# Get data from active datastore
mh_df = client.get_resource_data(package)
mh_df.head()
# Out:
#    _id  OBJECTID                              AGENCY_NAME  \
# 0    1      1236                    St Michael's Hospital
# 1    2      1237                    St Michael's Hospital
# 2    3      1238             WoodGreen Community Services
# 3    4      1239  Bangladeshi Canadian Community Services
# 4    5      1240    Harriet Tubman Community Organization
#
#                                 ORGANIZATION_ADDRESS  \
# 0              21 McGill St, Toronto, ON     M5B 1H3
# 1                30 Bond St, Toronto, ON     M5B 1W8
# 2  815 Danforth Ave, Ste 300, Toronto, ON     M4J...
# 3         2899 Danforth Ave, Toronto, ON     M4C 1M3
# 4  1761 Sheppard Ave E, Main Fl, Street Level, To...
#
#                   NEIGHBOURHOOD  \
# 0     Church-Yonge Corridor, 75
# 1     Church-Yonge Corridor, 75
# 2  Danforth Village-Toronto, 66
# 3         East End-Danforth, 62
# 4                Henry Farm, 53
#
#                                         OFFICE_PHONE  \
# 0                        Central Intake 416-864-5120
# 1  Office 416-864-5346 ; Emergency Department 416...
# 2                         416-645-6000 ext 2100/2200
# 3                                       416-699-4484
# 4                                       416-496-2042
#
#                         EMAIL  \
# 0                steps@smh.ca
# 1                         NaN
# 2  newcomerinfo@woodgreen.org
# 3       nakter@bangladeshi.ca
# 4    info@tubmancommunity.org
#
#                                              WEBSITE  \
# 0  <a href="http://www.stmichaelshospital.com/pro...
# 1  <a href="http://www.stmichaelshospital.com" ta...
# 2  <a href="http://www.woodgreen.org" target="_bl...
# 3  <a href="http://www.bangladeshi.ca" target="_b...
# 4  <a href="http://www.tubmancommunity.org" targe...
#
#                                          ELIGIBILITY  \
# 0  Youth 16-23 years experiencing a first episode...
# 1  People who need medical care for serious illne...
# 2  Newcomers (immigrants and refugees) * Mentorsh...
# 3  Open to all including immigrants and refugees ...
# 4  Focus on African-Canadian children, youth and ...
#
#                                  DESCRIPTION_SERVICE  ...  \
# 0  Assessment * treatment * support with school, ...  ...
# 1  Psychiatric emergencies -- Monday-Sunday 24 ho...  ...
# 2  <b>Settlement services</b> -- orientation, int...  ...
# 3  Settlement services * information and referral...  ...
# 4  Social and recreational programs * leadership ...  ...
#
#           DATE_UPDATED ADDRESS_POINT_ID   X   Y LONGITUDE LATITUDE  \
# 0  2013-10-21T04:00:00           840654 NaN NaN       NaN      NaN
# 1  2013-10-16T04:00:00           773891 NaN NaN       NaN      NaN
# 2  2016-01-25T05:00:00          7569237 NaN NaN       NaN      NaN
# 3  2015-09-15T04:00:00           790475 NaN NaN       NaN      NaN
# 4  2015-07-15T04:00:00         30013252 NaN NaN       NaN      NaN
#
#           ADDRESS_FULL    MUNICIPALITY  POSTAL_CODE  \
# 0         21 McGill St  former Toronto      M5B 1H3
# 1           30 Bond St  former Toronto      M5B 1W8
# 2     815 Danforth Ave  former Toronto      M4J 1L2
# 3    2899 Danforth Ave  former Toronto      M4C 1M3
# 4  1761 Sheppard Ave E      North York      M2J 0A5
#
#                                             geometry
# 0  {"type": "Point", "coordinates": [-79.38137399...
# 1  {"type": "Point", "coordinates": [-79.37767928...
# 2  {"type": "Point", "coordinates": [-79.34097126...
# 3  {"type": "Point", "coordinates": [-79.29397796...
# 4  {"type": "Point", "coordinates": [-79.34303694...
#
# [5 rows x 25 columns]

# %%
mh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   99 non-null     int64
#  1   OBJECTID              99 non-null     int64
#  2   AGENCY_NAME           99 non-null     object
#  3   ORGANIZATION_ADDRESS  99 non-null     object
#  4   NEIGHBOURHOOD         97 non-null     object
#  5   OFFICE_PHONE          98 non-null     object
#  6   EMAIL                 83 non-null     object
#  7   WEBSITE               99 non-null     object
#  8   ELIGIBILITY           94 non-null     object
#  9   DESCRIPTION_SERVICE   99 non-null     object
#  10  APPLICATION           88 non-null     object
#  11  LANGUAGES             99 non-null     object
#  12  ACCESSIBILITY         99 non-null     object
#  13  HOURS                 92 non-null     object
#  14  LEGAL_STATUS          98 non-null     object
#  15  DATE_UPDATED          99 non-null     object
#  16  ADDRESS_POINT_ID      99 non-null     int64
#  17  X                     0 non-null      float64
#  18  Y                     0 non-null      float64
#  19  LONGITUDE             0 non-null      float64
#  20  LATITUDE              0 non-null      float64
#  21  ADDRESS_FULL          99 non-null     object
#  22  MUNICIPALITY          99 non-null     object
#  23  POSTAL_CODE           99 non-null     object
#  24  geometry              99 non-null     object
# dtypes: float64(4), int64(3), object(18)
# memory usage: 19.5+ KB

# %%
mh_df = mh_df[[
    'OBJECTID',
    'AGENCY_NAME',
    'ORGANIZATION_ADDRESS',
    'NEIGHBOURHOOD',
    'LEGAL_STATUS',
    'DATE_UPDATED',
    'ADDRESS_FULL',
    'MUNICIPALITY',
    'POSTAL_CODE',
    'geometry'
]]
mh_df
# Out:
#     OBJECTID                                        AGENCY_NAME  \
# 0       1236                              St Michael's Hospital
# 1       1237                              St Michael's Hospital
# 2       1238                       WoodGreen Community Services
# 3       1239            Bangladeshi Canadian Community Services
# 4       1240              Harriet Tubman Community Organization
# ..       ...                                                ...
# 94      1233             Centre for Addiction and Mental Health
# 95      1234             Centre for Addiction and Mental Health
# 96      1235         Vasantham, A Tamil Seniors Wellness Centre
# 97      1241                                    Youth Unlimited
# 98      1242  WoodGreen Community Services - WoodGreen Commu...
#
#                                  ORGANIZATION_ADDRESS  \
# 0               21 McGill St, Toronto, ON     M5B 1H3
# 1                 30 Bond St, Toronto, ON     M5B 1W8
# 2   815 Danforth Ave, Ste 300, Toronto, ON     M4J...
# 3          2899 Danforth Ave, Toronto, ON     M4C 1M3
# 4   1761 Sheppard Ave E, Main Fl, Street Level, To...
# ..                                                ...
# 94  Intergenerational Wellness Centre, 80 Workman ...
# 95  Intergenerational Wellness Centre, 80 Workman ...
# 96  Easttown Centre Plaza, 2660 Eglinton Ave E, To...
# 97              57 Mobile Dr, Toronto, ON     M4A 1H5
# 98  250 Dundas St W, Ste 305, Toronto, ON     M4J 1L2
#
#                    NEIGHBOURHOOD                               LEGAL_STATUS  \
# 0      Church-Yonge Corridor, 75                            (50) Non Profit
# 1      Church-Yonge Corridor, 75                            (50) Non Profit
# 2   Danforth Village-Toronto, 66  (50) Non Profit ; (51) Registered Charity
# 3          East End-Danforth, 62  (50) Non Profit ; (51) Registered Charity
# 4                 Henry Farm, 53                            (50) Non Profit
# ..                           ...                                        ...
# 94                   Niagara, 82  (50) Non Profit ; (51) Registered Charity
# 95                   Niagara, 82  (50) Non Profit ; (51) Registered Charity
# 96            Eglinton East, 138                            (50) Non Profit
# 97          Victoria Village, 43                            (50) Non Profit
# 98                           NaN                            (50) Non Profit
#
#            DATE_UPDATED         ADDRESS_FULL    MUNICIPALITY POSTAL_CODE  \
# 0   2013-10-21T04:00:00         21 McGill St  former Toronto     M5B 1H3
# 1   2013-10-16T04:00:00           30 Bond St  former Toronto     M5B 1W8
# 2   2016-01-25T05:00:00     815 Danforth Ave  former Toronto     M4J 1L2
# 3   2015-09-15T04:00:00    2899 Danforth Ave  former Toronto     M4C 1M3
# 4   2015-07-15T04:00:00  1761 Sheppard Ave E      North York     M2J 0A5
# ..                  ...                  ...             ...         ...
# 94  2013-02-07T05:00:00       80 Workman Way  former Toronto     M6J 1H4
# 95  2013-02-06T05:00:00       80 Workman Way  former Toronto     M6J 1H4
# 96  2015-02-12T05:00:00  2660 Eglinton Ave E     Scarborough     M1K 2S3
# 97  2015-01-19T05:00:00         57 Mobile Dr      North York     M4A 1H5
# 98  2015-10-28T04:00:00      250 Dundas St W  former Toronto     M5T 2Z5
#
#                                              geometry
# 0   {"type": "Point", "coordinates": [-79.38137399...
# 1   {"type": "Point", "coordinates": [-79.37767928...
# 2   {"type": "Point", "coordinates": [-79.34097126...
# 3   {"type": "Point", "coordinates": [-79.29397796...
# 4   {"type": "Point", "coordinates": [-79.34303694...
# ..                                                ...
# 94  {"type": "Point", "coordinates": [-79.41743080...
# 95  {"type": "Point", "coordinates": [-79.41743080...
# 96  {"type": "Point", "coordinates": [-79.25149414...
# 97  {"type": "Point", "coordinates": [-79.31903689...
# 98  {"type": "Point", "coordinates": [-79.38979490...
#
# [99 rows x 10 columns]

# %%
mh_df['wellbeing_youth_type'] = 'mental-health'

# %% [markdown]
# ### Concurrent Disorder Programs

# %%
# Get package metadata using dataset id
package = client.get_package("wellbeing-youth-concurrent-disorder-programs")
# Check resources in package
# client.show_resources_info(package)

# %%
# Get data from active datastore
cdp_df = client.get_resource_data(package)
cdp_df.head()
# Out:
#    _id  OBJECTID                                        AGENCY_NAME  \
# 0    1      1243             Accommodation, Information and Support
# 1    2      1244                           Bellwood Health Services
# 2    3      1245                              Humber River Hospital
# 3    4      1246                                  Jean Tweed Centre
# 4    5      1247  University Health Network, Toronto Western Hos...
#
#                                 ORGANIZATION_ADDRESS  \
# 0  720 Spadina Ave, Ste 316, Toronto, ON     M5S 2T9
# 1         1020 McNicoll Ave, Toronto, ON     M1W 2J6
# 2           1235 Wilson Ave, Toronto, ON     M3M 0B2
# 3             215 Evans Ave, Toronto, ON     M8Z 1J5
# 4  399 Bathurst St, East Wing, 9th Fl, Toronto, O...
#
#               NEIGHBOURHOOD  OFFICE_PHONE                    EMAIL  \
# 0            University, 79  416-504-3610  mbastidas@aistoronto.ca
# 1              Steeles, 116  416-495-0926         info@bellwood.ca
# 2  Downsview-Roding-CFB, 26  416-242-1000                      NaN
# 3                Mimico, 17  416-255-7359       info@jeantweed.com
# 4     Trinity-Bellwoods, 81  416-603-5974                      NaN
#
#                                              WEBSITE  \
# 0  <a href="http://www.aistoronto.ca" target="_bl...
# 1  <a href="http://www.bellwood.ca" target="_blan...
# 2  <a href="http://www.hrh.ca" target="_blank">ww...
# 3  <a href="http://www.jeantweed.com" target="_bl...
# 4  <a href="http://www.uhn.ca" target="_blank">ww...
#
#                                          ELIGIBILITY  \
# 0  Individuals 16 years and older, single or with...
# 1  Women and men 19 years and older, with alcohol...
# 2                                                NaN
# 3  Women 16 years and older who have problems wit...
# 4  Portuguese speaking people with a mental healt...
#
#                                  DESCRIPTION_SERVICE  ...  \
# 0  Permanent supportive housing * bachelor, one a...  ...
# 1  Residential and outpatient addiction treatment...  ...
# 2  Acute care hospital * medical and surgical inp...  ...
# 3  Intensive 3 week residential and day treatment...  ...
# 4  Linguistically and culturally appropriate ment...  ...
#
#           DATE_UPDATED ADDRESS_POINT_ID   X   Y LONGITUDE LATITUDE  \
# 0  2015-05-07T04:00:00           870176 NaN NaN       NaN      NaN
# 1  2014-10-15T04:00:00          9311782 NaN NaN       NaN      NaN
# 2  2015-10-16T04:00:00         30063647 NaN NaN       NaN      NaN
# 3  2016-01-07T05:00:00         10998869 NaN NaN       NaN      NaN
# 4  2014-01-31T05:00:00          9086232 NaN NaN       NaN      NaN
#
#         ADDRESS_FULL    MUNICIPALITY  POSTAL_CODE  \
# 0    720 Spadina Ave  former Toronto      M5S 2T9
# 1  1020 McNicoll Ave     Scarborough      M1W 2J6
# 2    1235 Wilson Ave      North York      M3M 0B2
# 3      215 Evans Ave       Etobicoke      M8Z 1J5
# 4    399 Bathurst St  former Toronto      M5T 2S8
#
#                                             geometry
# 0  {"type": "Point", "coordinates": [-79.40361735...
# 1  {"type": "Point", "coordinates": [-79.33600977...
# 2  {"type": "Point", "coordinates": [-79.48921562...
# 3  {"type": "Point", "coordinates": [-79.51552302...
# 4  {"type": "Point", "coordinates": [-79.40568847...
#
# [5 rows x 25 columns]

# %%
cdp_df = cdp_df[[
    'OBJECTID',
    'AGENCY_NAME',
    'ORGANIZATION_ADDRESS',
    'NEIGHBOURHOOD',
    'LEGAL_STATUS',
    'DATE_UPDATED',
    'ADDRESS_FULL',
    'MUNICIPALITY',
    'POSTAL_CODE',
    'geometry'
]]
cdp_df.head()
# Out:
#    OBJECTID                                        AGENCY_NAME  \
# 0      1243             Accommodation, Information and Support
# 1      1244                           Bellwood Health Services
# 2      1245                              Humber River Hospital
# 3      1246                                  Jean Tweed Centre
# 4      1247  University Health Network, Toronto Western Hos...
#
#                                 ORGANIZATION_ADDRESS  \
# 0  720 Spadina Ave, Ste 316, Toronto, ON     M5S 2T9
# 1         1020 McNicoll Ave, Toronto, ON     M1W 2J6
# 2           1235 Wilson Ave, Toronto, ON     M3M 0B2
# 3             215 Evans Ave, Toronto, ON     M8Z 1J5
# 4  399 Bathurst St, East Wing, 9th Fl, Toronto, O...
#
#               NEIGHBOURHOOD                               LEGAL_STATUS  \
# 0            University, 79  (50) Non Profit ; (51) Registered Charity
# 1              Steeles, 116                            (50) Non Profit
# 2  Downsview-Roding-CFB, 26  (50) Non Profit ; (51) Registered Charity
# 3                Mimico, 17  (50) Non Profit ; (51) Registered Charity
# 4     Trinity-Bellwoods, 81  (50) Non Profit ; (51) Registered Charity
#
#           DATE_UPDATED       ADDRESS_FULL    MUNICIPALITY POSTAL_CODE  \
# 0  2015-05-07T04:00:00    720 Spadina Ave  former Toronto     M5S 2T9
# 1  2014-10-15T04:00:00  1020 McNicoll Ave     Scarborough     M1W 2J6
# 2  2015-10-16T04:00:00    1235 Wilson Ave      North York     M3M 0B2
# 3  2016-01-07T05:00:00      215 Evans Ave       Etobicoke     M8Z 1J5
# 4  2014-01-31T05:00:00    399 Bathurst St  former Toronto     M5T 2S8
#
#                                             geometry
# 0  {"type": "Point", "coordinates": [-79.40361735...
# 1  {"type": "Point", "coordinates": [-79.33600977...
# 2  {"type": "Point", "coordinates": [-79.48921562...
# 3  {"type": "Point", "coordinates": [-79.51552302...
# 4  {"type": "Point", "coordinates": [-79.40568847...

# %%
cdp_df['wellbeing_youth_type'] = 'concurrent-disorder-programs'

# %% [markdown]
# ### Union of both wellbeing youth datasets

# %%
srv_df = pd.concat(
    [mh_df, cdp_df],
    axis=0,
    ignore_index=True
)
srv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID              125 non-null    int64
#  1   AGENCY_NAME           125 non-null    object
#  2   ORGANIZATION_ADDRESS  125 non-null    object
#  3   NEIGHBOURHOOD         123 non-null    object
#  4   LEGAL_STATUS          124 non-null    object
#  5   DATE_UPDATED          125 non-null    object
#  6   ADDRESS_FULL          125 non-null    object
#  7   MUNICIPALITY          125 non-null    object
#  8   POSTAL_CODE           125 non-null    object
#  9   geometry              125 non-null    object
#  10  wellbeing_youth_type  125 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 10.9+ KB

# %%
# convert geojson geometry to list of dictionaries
points_list = [
        dict([
                i.split(': ')
                for i in s.replace('"', '')[1:-1].split(', ', 1)
        ])
        for s in srv_df['geometry']
    ]
for p in points_list:
    p['coordinates'] = p['coordinates'][1:-1].split(', ')
points_list[0:3]
# Out:
# [{'type': 'Point', 'coordinates': ['-79.3813739919446', '43.6598728550589']},
#  {'type': 'Point', 'coordinates': ['-79.3776792804321', '43.6536468859287']},
#  {'type': 'Point', 'coordinates': ['-79.3409712694603', '43.6794389537811']}]

# %%
# extract coordinates and add them to df
srv_df[['longitude','latitude']] = pd.DataFrame(
    pd.json_normalize(points_list)['coordinates'].tolist(),
    index=srv_df.index
)
srv_df.head(3)
# Out:
#    OBJECTID                   AGENCY_NAME  \
# 0      1236         St Michael's Hospital
# 1      1237         St Michael's Hospital
# 2      1238  WoodGreen Community Services
#
#                                 ORGANIZATION_ADDRESS  \
# 0              21 McGill St, Toronto, ON     M5B 1H3
# 1                30 Bond St, Toronto, ON     M5B 1W8
# 2  815 Danforth Ave, Ste 300, Toronto, ON     M4J...
#
#                   NEIGHBOURHOOD                               LEGAL_STATUS  \
# 0     Church-Yonge Corridor, 75                            (50) Non Profit
# 1     Church-Yonge Corridor, 75                            (50) Non Profit
# 2  Danforth Village-Toronto, 66  (50) Non Profit ; (51) Registered Charity
#
#           DATE_UPDATED      ADDRESS_FULL    MUNICIPALITY POSTAL_CODE  \
# 0  2013-10-21T04:00:00      21 McGill St  former Toronto     M5B 1H3
# 1  2013-10-16T04:00:00        30 Bond St  former Toronto     M5B 1W8
# 2  2016-01-25T05:00:00  815 Danforth Ave  former Toronto     M4J 1L2
#
#                                             geometry wellbeing_youth_type  \
# 0  {"type": "Point", "coordinates": [-79.38137399...        mental-health
# 1  {"type": "Point", "coordinates": [-79.37767928...        mental-health
# 2  {"type": "Point", "coordinates": [-79.34097126...        mental-health
#
#            longitude          latitude
# 0  -79.3813739919446  43.6598728550589
# 1  -79.3776792804321  43.6536468859287
# 2  -79.3409712694603  43.6794389537811

# %%
# drop geometry column
srv_df.drop(columns=['geometry'], inplace=True)
srv_df.head()
# Out:
#    OBJECTID                              AGENCY_NAME  \
# 0      1236                    St Michael's Hospital
# 1      1237                    St Michael's Hospital
# 2      1238             WoodGreen Community Services
# 3      1239  Bangladeshi Canadian Community Services
# 4      1240    Harriet Tubman Community Organization
#
#                                 ORGANIZATION_ADDRESS  \
# 0              21 McGill St, Toronto, ON     M5B 1H3
# 1                30 Bond St, Toronto, ON     M5B 1W8
# 2  815 Danforth Ave, Ste 300, Toronto, ON     M4J...
# 3         2899 Danforth Ave, Toronto, ON     M4C 1M3
# 4  1761 Sheppard Ave E, Main Fl, Street Level, To...
#
#                   NEIGHBOURHOOD                               LEGAL_STATUS  \
# 0     Church-Yonge Corridor, 75                            (50) Non Profit
# 1     Church-Yonge Corridor, 75                            (50) Non Profit
# 2  Danforth Village-Toronto, 66  (50) Non Profit ; (51) Registered Charity
# 3         East End-Danforth, 62  (50) Non Profit ; (51) Registered Charity
# 4                Henry Farm, 53                            (50) Non Profit
#
#           DATE_UPDATED         ADDRESS_FULL    MUNICIPALITY POSTAL_CODE  \
# 0  2013-10-21T04:00:00         21 McGill St  former Toronto     M5B 1H3
# 1  2013-10-16T04:00:00           30 Bond St  former Toronto     M5B 1W8
# 2  2016-01-25T05:00:00     815 Danforth Ave  former Toronto     M4J 1L2
# 3  2015-09-15T04:00:00    2899 Danforth Ave  former Toronto     M4C 1M3
# 4  2015-07-15T04:00:00  1761 Sheppard Ave E      North York     M2J 0A5
#
#   wellbeing_youth_type          longitude          latitude
# 0        mental-health  -79.3813739919446  43.6598728550589
# 1        mental-health  -79.3776792804321  43.6536468859287
# 2        mental-health  -79.3409712694603  43.6794389537811
# 3        mental-health  -79.2939779674297  43.6896991337791
# 4        mental-health  -79.3430369482099  43.7756095392188

# %%
srv_df['NEIGHBOURHOOD'] = srv_df['NEIGHBOURHOOD'].str.replace(', ', ' (') + ')'

# %%
srv_df.groupby('MUNICIPALITY').count()
# Out:
#                 OBJECTID  AGENCY_NAME  ORGANIZATION_ADDRESS  NEIGHBOURHOOD  \
# MUNICIPALITY
# East York              1            1                     1              1
# Etobicoke              8            8                     8              8
# North York            17           17                    17             17
# Scarborough           17           17                    17             16
# York                   6            6                     6              6
# former Toronto        76           76                    76             75
#
#                 LEGAL_STATUS  DATE_UPDATED  ADDRESS_FULL  POSTAL_CODE  \
# MUNICIPALITY
# East York                  1             1             1            1
# Etobicoke                  8             8             8            8
# North York                17            17            17           17
# Scarborough               16            17            17           17
# York                       6             6             6            6
# former Toronto            76            76            76           76
#
#                 wellbeing_youth_type  longitude  latitude
# MUNICIPALITY
# East York                          1          1         1
# Etobicoke                          8          8         8
# North York                        17         17        17
# Scarborough                       17         17        17
# York                               6          6         6
# former Toronto                    76         76        76

# %%
years = pd.DataFrame({
    'year': [*range(2014, datetime.today().year + 1)],
    'key': 0
})
years
# Out:
#     year  key
# 0   2014    0
# 1   2015    0
# 2   2016    0
# 3   2017    0
# 4   2018    0
# 5   2019    0
# 6   2020    0
# 7   2021    0
# 8   2022    0
# 9   2023    0
# 10  2024    0

# %%
srv_df['key'] = 0
srv_df = (srv_df
    .merge(years, on='key', how='outer')
    .drop(columns=['key'])
)
srv_df.head()
# Out:
#    OBJECTID            AGENCY_NAME                   ORGANIZATION_ADDRESS  \
# 0      1236  St Michael's Hospital  21 McGill St, Toronto, ON     M5B 1H3
# 1      1236  St Michael's Hospital  21 McGill St, Toronto, ON     M5B 1H3
# 2      1236  St Michael's Hospital  21 McGill St, Toronto, ON     M5B 1H3
# 3      1236  St Michael's Hospital  21 McGill St, Toronto, ON     M5B 1H3
# 4      1236  St Michael's Hospital  21 McGill St, Toronto, ON     M5B 1H3
#
#                 NEIGHBOURHOOD     LEGAL_STATUS         DATE_UPDATED  \
# 0  Church-Yonge Corridor (75)  (50) Non Profit  2013-10-21T04:00:00
# 1  Church-Yonge Corridor (75)  (50) Non Profit  2013-10-21T04:00:00
# 2  Church-Yonge Corridor (75)  (50) Non Profit  2013-10-21T04:00:00
# 3  Church-Yonge Corridor (75)  (50) Non Profit  2013-10-21T04:00:00
# 4  Church-Yonge Corridor (75)  (50) Non Profit  2013-10-21T04:00:00
#
#    ADDRESS_FULL    MUNICIPALITY POSTAL_CODE wellbeing_youth_type  \
# 0  21 McGill St  former Toronto     M5B 1H3        mental-health
# 1  21 McGill St  former Toronto     M5B 1H3        mental-health
# 2  21 McGill St  former Toronto     M5B 1H3        mental-health
# 3  21 McGill St  former Toronto     M5B 1H3        mental-health
# 4  21 McGill St  former Toronto     M5B 1H3        mental-health
#
#            longitude          latitude  year
# 0  -79.3813739919446  43.6598728550589  2014
# 1  -79.3813739919446  43.6598728550589  2015
# 2  -79.3813739919446  43.6598728550589  2016
# 3  -79.3813739919446  43.6598728550589  2017
# 4  -79.3813739919446  43.6598728550589  2018

# %%
# Save to csv
srv_df.to_csv(
    '../data/processed/mh_services.csv',
    header=True,
    index=False
)

# %% [markdown]
# ---
#
# ## Mental Health Apprehensions

# %%
# Get package metadata using dataset id
package = client.get_package("mental-health-apprehensions")
# Check resources in package
# client.show_resources_info(package)

# %%
# Get data from active datastore resource
apr_df = client.get_resource_data(package)
apr_df.head()
# Out:
#    _id EVENT_UNIQUE_ID REPORT_DATE  REPORT_YEAR REPORT_MONTH REPORT_DOW  \
# 0    1  GO-20141262056  2014-01-01         2014      January  Wednesday
# 1    2  GO-20141263993  2014-01-01         2014      January  Wednesday
# 2    3  GO-20141261310  2014-01-01         2014      January  Wednesday
# 3    4  GO-20141259983  2014-01-01         2014      January  Wednesday
# 4    5  GO-20141263946  2014-01-01         2014      January  Wednesday
#
#    REPORT_DOY  REPORT_DAY  REPORT_HOUR    OCC_DATE  ...  OCC_HOUR DIVISION  \
# 0           1           1         11.0  2014-01-01  ...      11.0      D13
# 1           1           1         19.0  2014-01-01  ...      19.0      D12
# 2           1           1          8.0  2014-01-01  ...       6.0      NSA
# 3           1           1          NaN  2014-01-01  ...       NaN      D23
# 4           1           1         19.0  2014-01-01  ...      19.0      D42
#
#    PREMISES_TYPE          APPREHENSION_TYPE     SEX  AGE_COHORT HOOD_158  \
# 0          House  Mha Sec 17 (Power Of App)    Male    25 to 34      092
# 1      Apartment  Mha Sec 17 (Power Of App)    Male    18 to 24      115
# 2        Outside  Mha Sec 17 (Power Of App)  Female    55 to 64      NSA
# 3          House  Mha Sec 17 (Power Of App)  Female    45 to 54      007
# 4          House  Mha Sec 17 (Power Of App)    Male    55 to 64      144
#
#                       NEIGHBOURHOOD_158 HOOD_140  \
# 0           Corso Italia-Davenport (92)      092
# 1                    Mount Dennis (115)      115
# 2                                   NSA      NSA
# 3  Willowridge-Martingrove-Richview (7)      007
# 4             Morningside Heights (144)      131
#
#                       NEIGHBOURHOOD_140
# 0           Corso Italia-Davenport (92)
# 1                    Mount Dennis (115)
# 2                                   NSA
# 3  Willowridge-Martingrove-Richview (7)
# 4                           Rouge (131)
#
# [5 rows x 25 columns]

# %%
apr_df.columns
# Out:
# Index(['_id', 'EVENT_UNIQUE_ID', 'REPORT_DATE', 'REPORT_YEAR', 'REPORT_MONTH',
#        'REPORT_DOW', 'REPORT_DOY', 'REPORT_DAY', 'REPORT_HOUR', 'OCC_DATE',
#        'OCC_YEAR', 'OCC_MONTH', 'OCC_DOY', 'OCC_DAY', 'OCC_DOW', 'OCC_HOUR',
#        'DIVISION', 'PREMISES_TYPE', 'APPREHENSION_TYPE', 'SEX', 'AGE_COHORT',
#        'HOOD_158', 'NEIGHBOURHOOD_158', 'HOOD_140', 'NEIGHBOURHOOD_140'],
#       dtype='object')

# %%
apr_df = apr_df[[
    'EVENT_UNIQUE_ID',
    'REPORT_DATE',
    'OCC_DATE',
    'OCC_YEAR',
    'DIVISION',
    'PREMISES_TYPE',
    'APPREHENSION_TYPE',
    'SEX',
    'AGE_COHORT',
    'HOOD_158',
    'NEIGHBOURHOOD_158'
]]

# %%
apr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112314 entries, 0 to 112313
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   EVENT_UNIQUE_ID    112314 non-null  object
#  1   REPORT_DATE        112314 non-null  object
#  2   OCC_DATE           112314 non-null  object
#  3   OCC_YEAR           112314 non-null  int64
#  4   DIVISION           112314 non-null  object
#  5   PREMISES_TYPE      112314 non-null  object
#  6   APPREHENSION_TYPE  112314 non-null  object
#  7   SEX                112314 non-null  object
#  8   AGE_COHORT         112314 non-null  object
#  9   HOOD_158           112314 non-null  object
#  10  NEIGHBOURHOOD_158  112314 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 9.4+ MB

# %%
apr_df['OCC_YEAR'].unique()
# Out:
# array([2014, 2013, 2012, 2015, 2016, 2010, 2017, 2018, 2019, 2020, 2021,
#        2022, 2002, 2023, 2024])

# %%
# Keep only apprehensions that occurred 2014 or later
apr_df = apr_df.loc[apr_df['OCC_YEAR'] >= 2014]
apr_df['OCC_YEAR'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
# Save to csv
apr_df.to_csv(
    '../data/processed/mh_appr.csv',
    header=True,
    index=False
)

# %% [markdown]
# ---
#
# ## Neighbourhood geometry data

# %%
with open('../data/raw/Neighbourhoods - 4326.geojson') as f:
    gj = geojson.load(f)

# %%
for feature in gj['features']:
    # keep only necessary properties
    d = feature['properties']
    feature['properties'] = {
        k: v for k, v in d.items()
        if k in [
            'OBJECTID',
            'AREA_LONG_CODE',
            'AREA_DESC',
            'CLASSIFICATION',
            'CLASSIFICATION_CODE'
        ]
    }

# %%
# output data
with open('../data/processed/neighbourhoods.geojson', 'w') as f:
    geojson.dump(gj, f)
