# %%
import sys
sys.path.append('../..')

from common.toronto_api import TorontoOpenDataAPI

import pandas as pd
from datetime import datetime

# %%
# Initialize API client
client = TorontoOpenDataAPI()

# %% [markdown]
# ---
#
# ## Mental Health Apprehensions

# %%
# Get package metadata using dataset id
package = client.get_package("mental-health-apprehensions")

# %%
# Check resources in package
client.show_resources_info(package)
# Out:
# Number of resources: 4
#
# 0: mental-health-apprehensions
#     datastore_active: True
#     format: CSV
#     url_type: datastore
#
# 1: mental-health-apprehensions.xml
#     datastore_active: False
#     format: XML
#     url_type: upload
#
# 2: mental-health-apprehensions.json
#     datastore_active: False
#     format: JSON
#     url_type: upload
#
# 3: mental-health-apprehensions.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload

# %%
# Get data from active datastore resource
apr_df = client.get_resource_data(package)
apr_df.head()
# Out:
#    _id EVENT_UNIQUE_ID REPORT_DATE  REPORT_YEAR REPORT_MONTH REPORT_DOW  \
# 0    1  GO-20141262056  2014-01-01         2014      January  Wednesday
# 1    2  GO-20141263993  2014-01-01         2014      January  Wednesday
# 2    3  GO-20141261310  2014-01-01         2014      January  Wednesday
# 3    4  GO-20141259983  2014-01-01         2014      January  Wednesday
# 4    5  GO-20141263946  2014-01-01         2014      January  Wednesday
#
#    REPORT_DOY  REPORT_DAY  REPORT_HOUR    OCC_DATE  ...  OCC_HOUR DIVISION  \
# 0           1           1         11.0  2014-01-01  ...      11.0      D13
# 1           1           1         19.0  2014-01-01  ...      19.0      D12
# 2           1           1          8.0  2014-01-01  ...       6.0      NSA
# 3           1           1          NaN  2014-01-01  ...       NaN      D23
# 4           1           1         19.0  2014-01-01  ...      19.0      D42
#
#    PREMISES_TYPE          APPREHENSION_TYPE     SEX  AGE_COHORT HOOD_158  \
# 0          House  Mha Sec 17 (Power Of App)    Male    25 to 34      092
# 1      Apartment  Mha Sec 17 (Power Of App)    Male    18 to 24      115
# 2        Outside  Mha Sec 17 (Power Of App)  Female    55 to 64      NSA
# 3          House  Mha Sec 17 (Power Of App)  Female    45 to 54      007
# 4          House  Mha Sec 17 (Power Of App)    Male    55 to 64      144
#
#                       NEIGHBOURHOOD_158 HOOD_140  \
# 0           Corso Italia-Davenport (92)      092
# 1                    Mount Dennis (115)      115
# 2                                   NSA      NSA
# 3  Willowridge-Martingrove-Richview (7)      007
# 4             Morningside Heights (144)      131
#
#                       NEIGHBOURHOOD_140
# 0           Corso Italia-Davenport (92)
# 1                    Mount Dennis (115)
# 2                                   NSA
# 3  Willowridge-Martingrove-Richview (7)
# 4                           Rouge (131)
#
# [5 rows x 25 columns]

# %%
apr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112314 entries, 0 to 112313
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   _id                112314 non-null  int64
#  1   EVENT_UNIQUE_ID    112314 non-null  object
#  2   REPORT_DATE        112314 non-null  object
#  3   REPORT_YEAR        112314 non-null  int64
#  4   REPORT_MONTH       112314 non-null  object
#  5   REPORT_DOW         112314 non-null  object
#  6   REPORT_DOY         112314 non-null  int64
#  7   REPORT_DAY         112314 non-null  int64
#  8   REPORT_HOUR        108344 non-null  float64
#  9   OCC_DATE           112314 non-null  object
#  10  OCC_YEAR           112314 non-null  int64
#  11  OCC_MONTH          112314 non-null  object
#  12  OCC_DOY            112314 non-null  int64
#  13  OCC_DAY            112314 non-null  int64
#  14  OCC_DOW            112314 non-null  object
#  15  OCC_HOUR           108061 non-null  float64
#  16  DIVISION           112314 non-null  object
#  17  PREMISES_TYPE      112314 non-null  object
#  18  APPREHENSION_TYPE  112314 non-null  object
#  19  SEX                112314 non-null  object
#  20  AGE_COHORT         112314 non-null  object
#  21  HOOD_158           112314 non-null  object
#  22  NEIGHBOURHOOD_158  112314 non-null  object
#  23  HOOD_140           112314 non-null  object
#  24  NEIGHBOURHOOD_140  112314 non-null  object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 21.4+ MB

# %%
apr_df['REPORT_YEAR'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %% [markdown]
# ---
#
# ## Wellbeing Youth: Mental Health

# %%
# Get package metadata using dataset id
package = client.get_package("wellbeing-youth-mental-health")

# %%
# Check resources in package
client.show_resources_info(package)
# Out:
# Number of resources: 13
#
# 0: Mental Health
#     datastore_active: True
#     format: GeoJSON
#     url_type: datastore
#
# 1: Mental Health - 4326.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#
# 2: Mental Health - 2945.gpkg
#     datastore_active: False
#     format: GPKG
#     url_type: upload
#
# 3: Mental Health - 4326.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#
# 4: Mental Health - 2945.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#
# 5: Mental Health - 4326.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#
# 6: Mental Health - 2945.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#
# 7: Mental Health - 4326.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#
# 8: Mental Health - 2945.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#
# 9: Mental Health - 2952.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#
# 10: Mental Health - 2952.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#
# 11: Mental Health - 2952.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#
# 12: Mental Health - 2952.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload

# %%
# Get data from active datastore
mh_df = client.get_resource_data(package)

# %%
mh_df.head()
# Out:
#    _id  OBJECTID                              AGENCY_NAME  \
# 0    1      1236                    St Michael's Hospital
# 1    2      1237                    St Michael's Hospital
# 2    3      1238             WoodGreen Community Services
# 3    4      1239  Bangladeshi Canadian Community Services
# 4    5      1240    Harriet Tubman Community Organization
#
#                                 ORGANIZATION_ADDRESS  \
# 0              21 McGill St, Toronto, ON     M5B 1H3
# 1                30 Bond St, Toronto, ON     M5B 1W8
# 2  815 Danforth Ave, Ste 300, Toronto, ON     M4J...
# 3         2899 Danforth Ave, Toronto, ON     M4C 1M3
# 4  1761 Sheppard Ave E, Main Fl, Street Level, To...
#
#                   NEIGHBOURHOOD  \
# 0     Church-Yonge Corridor, 75
# 1     Church-Yonge Corridor, 75
# 2  Danforth Village-Toronto, 66
# 3         East End-Danforth, 62
# 4                Henry Farm, 53
#
#                                         OFFICE_PHONE  \
# 0                        Central Intake 416-864-5120
# 1  Office 416-864-5346 ; Emergency Department 416...
# 2                         416-645-6000 ext 2100/2200
# 3                                       416-699-4484
# 4                                       416-496-2042
#
#                         EMAIL  \
# 0                steps@smh.ca
# 1                         NaN
# 2  newcomerinfo@woodgreen.org
# 3       nakter@bangladeshi.ca
# 4    info@tubmancommunity.org
#
#                                              WEBSITE  \
# 0  <a href="http://www.stmichaelshospital.com/pro...
# 1  <a href="http://www.stmichaelshospital.com" ta...
# 2  <a href="http://www.woodgreen.org" target="_bl...
# 3  <a href="http://www.bangladeshi.ca" target="_b...
# 4  <a href="http://www.tubmancommunity.org" targe...
#
#                                          ELIGIBILITY  \
# 0  Youth 16-23 years experiencing a first episode...
# 1  People who need medical care for serious illne...
# 2  Newcomers (immigrants and refugees) * Mentorsh...
# 3  Open to all including immigrants and refugees ...
# 4  Focus on African-Canadian children, youth and ...
#
#                                  DESCRIPTION_SERVICE  ...  \
# 0  Assessment * treatment * support with school, ...  ...
# 1  Psychiatric emergencies -- Monday-Sunday 24 ho...  ...
# 2  <b>Settlement services</b> -- orientation, int...  ...
# 3  Settlement services * information and referral...  ...
# 4  Social and recreational programs * leadership ...  ...
#
#           DATE_UPDATED ADDRESS_POINT_ID   X   Y LONGITUDE LATITUDE  \
# 0  2013-10-21T04:00:00           840654 NaN NaN       NaN      NaN
# 1  2013-10-16T04:00:00           773891 NaN NaN       NaN      NaN
# 2  2016-01-25T05:00:00          7569237 NaN NaN       NaN      NaN
# 3  2015-09-15T04:00:00           790475 NaN NaN       NaN      NaN
# 4  2015-07-15T04:00:00         30013252 NaN NaN       NaN      NaN
#
#           ADDRESS_FULL    MUNICIPALITY  POSTAL_CODE  \
# 0         21 McGill St  former Toronto      M5B 1H3
# 1           30 Bond St  former Toronto      M5B 1W8
# 2     815 Danforth Ave  former Toronto      M4J 1L2
# 3    2899 Danforth Ave  former Toronto      M4C 1M3
# 4  1761 Sheppard Ave E      North York      M2J 0A5
#
#                                             geometry
# 0  {"type": "Point", "coordinates": [-79.38137399...
# 1  {"type": "Point", "coordinates": [-79.37767928...
# 2  {"type": "Point", "coordinates": [-79.34097126...
# 3  {"type": "Point", "coordinates": [-79.29397796...
# 4  {"type": "Point", "coordinates": [-79.34303694...
#
# [5 rows x 25 columns]

# %% [markdown]
# ---
#
# ## Wellbeing Youth: Concurrent Disorder Programs

# %%
# Get package metadata using dataset id
package = client.get_package("wellbeing-youth-concurrent-disorder-programs")

# %%
# Check resources in package
client.show_resources_info(package)
# Out:
# Number of resources: 13
#
# 0: Concurrent Disorder Programs
#     datastore_active: True
#     format: GeoJSON
#     url_type: datastore
#
# 1: Concurrent Disorder Programs - 4326.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#
# 2: Concurrent Disorder Programs - 2945.gpkg
#     datastore_active: False
#     format: GPKG
#     url_type: upload
#
# 3: Concurrent Disorder Programs - 4326.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#
# 4: Concurrent Disorder Programs - 2945.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#
# 5: Concurrent Disorder Programs - 4326.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#
# 6: Concurrent Disorder Programs - 2945.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#
# 7: Concurrent Disorder Programs - 4326.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#
# 8: Concurrent Disorder Programs - 2945.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#
# 9: Concurrent Disorder Programs - 2952.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#
# 10: Concurrent Disorder Programs - 2952.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#
# 11: Concurrent Disorder Programs - 2952.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#
# 12: Concurrent Disorder Programs - 2952.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload

# %%
# Get data from active datastore
cdp_df = client.get_resource_data(package)
cdp_df.head()
# Out:
#    _id  OBJECTID                                        AGENCY_NAME  \
# 0    1      1243             Accommodation, Information and Support
# 1    2      1244                           Bellwood Health Services
# 2    3      1245                              Humber River Hospital
# 3    4      1246                                  Jean Tweed Centre
# 4    5      1247  University Health Network, Toronto Western Hos...
#
#                                 ORGANIZATION_ADDRESS  \
# 0  720 Spadina Ave, Ste 316, Toronto, ON     M5S 2T9
# 1         1020 McNicoll Ave, Toronto, ON     M1W 2J6
# 2           1235 Wilson Ave, Toronto, ON     M3M 0B2
# 3             215 Evans Ave, Toronto, ON     M8Z 1J5
# 4  399 Bathurst St, East Wing, 9th Fl, Toronto, O...
#
#               NEIGHBOURHOOD  OFFICE_PHONE                    EMAIL  \
# 0            University, 79  416-504-3610  mbastidas@aistoronto.ca
# 1              Steeles, 116  416-495-0926         info@bellwood.ca
# 2  Downsview-Roding-CFB, 26  416-242-1000                      NaN
# 3                Mimico, 17  416-255-7359       info@jeantweed.com
# 4     Trinity-Bellwoods, 81  416-603-5974                      NaN
#
#                                              WEBSITE  \
# 0  <a href="http://www.aistoronto.ca" target="_bl...
# 1  <a href="http://www.bellwood.ca" target="_blan...
# 2  <a href="http://www.hrh.ca" target="_blank">ww...
# 3  <a href="http://www.jeantweed.com" target="_bl...
# 4  <a href="http://www.uhn.ca" target="_blank">ww...
#
#                                          ELIGIBILITY  \
# 0  Individuals 16 years and older, single or with...
# 1  Women and men 19 years and older, with alcohol...
# 2                                                NaN
# 3  Women 16 years and older who have problems wit...
# 4  Portuguese speaking people with a mental healt...
#
#                                  DESCRIPTION_SERVICE  ...  \
# 0  Permanent supportive housing * bachelor, one a...  ...
# 1  Residential and outpatient addiction treatment...  ...
# 2  Acute care hospital * medical and surgical inp...  ...
# 3  Intensive 3 week residential and day treatment...  ...
# 4  Linguistically and culturally appropriate ment...  ...
#
#           DATE_UPDATED ADDRESS_POINT_ID   X   Y LONGITUDE LATITUDE  \
# 0  2015-05-07T04:00:00           870176 NaN NaN       NaN      NaN
# 1  2014-10-15T04:00:00          9311782 NaN NaN       NaN      NaN
# 2  2015-10-16T04:00:00         30063647 NaN NaN       NaN      NaN
# 3  2016-01-07T05:00:00         10998869 NaN NaN       NaN      NaN
# 4  2014-01-31T05:00:00          9086232 NaN NaN       NaN      NaN
#
#         ADDRESS_FULL    MUNICIPALITY  POSTAL_CODE  \
# 0    720 Spadina Ave  former Toronto      M5S 2T9
# 1  1020 McNicoll Ave     Scarborough      M1W 2J6
# 2    1235 Wilson Ave      North York      M3M 0B2
# 3      215 Evans Ave       Etobicoke      M8Z 1J5
# 4    399 Bathurst St  former Toronto      M5T 2S8
#
#                                             geometry
# 0  {"type": "Point", "coordinates": [-79.40361735...
# 1  {"type": "Point", "coordinates": [-79.33600977...
# 2  {"type": "Point", "coordinates": [-79.48921562...
# 3  {"type": "Point", "coordinates": [-79.51552302...
# 4  {"type": "Point", "coordinates": [-79.40568847...
#
# [5 rows x 25 columns]
