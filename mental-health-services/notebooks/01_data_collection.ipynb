# %%
import sys
sys.path.append('../..')

from common.toronto_api import TorontoOpenDataAPI

import pandas as pd
from datetime import datetime

# %%
# Initialize API client
client = TorontoOpenDataAPI()

# %% [markdown]
# ---
#
# ## Mental Health Apprehensions

# %%
# Get package metadata using dataset id
# Description url:
# https://open.toronto.ca/dataset/mental-health-apprehensions/
package = client.get_package("mental-health-apprehensions")

# %%
# Check resources in package
print(f'Number of resources: {package["num_resources"]}\n')
for idx, resource in enumerate(package["resources"]):
    print(f'''{idx}: {resource["name"]}
    Active: {resource["datastore_active"]}
    url type: {resource["url_type"]}
''')
# Out:
# Number of resources: 4
#
# 0: mental-health-apprehensions
#     Active: True
#     url type: datastore
#
# 1: mental-health-apprehensions.xml
#     Active: False
#     url type: upload
#
# 2: mental-health-apprehensions.json
#     Active: False
#     url type: upload
#
# 3: mental-health-apprehensions.csv
#     Active: False
#     url type: upload

# %%
# Get resource data:
for idx, resource in enumerate(package["resources"]):

    # from cached csv:
    if not resource["datastore_active"] and resource['format']=='CSV':
        print(f'**getting data from cached csv**')
        print(f'\t{resource["url"]}')
        apprehensions_df = pd.read_csv(resource["url"])

apprehensions_df.head()
# Out:
# **getting data from cached csv**
# 	https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/mental-health-apprehensions/resource/4a92540b-6504-4b25-827d-4511b8b9f3d9/download/mental-health-apprehensions.csv
#    _id EVENT_UNIQUE_ID REPORT_DATE  REPORT_YEAR REPORT_MONTH REPORT_DOW  \
# 0    1  GO-20141262056  2014-01-01         2014      January  Wednesday
# 1    2  GO-20141263993  2014-01-01         2014      January  Wednesday
# 2    3  GO-20141261310  2014-01-01         2014      January  Wednesday
# 3    4  GO-20141259983  2014-01-01         2014      January  Wednesday
# 4    5  GO-20141263946  2014-01-01         2014      January  Wednesday
#
#    REPORT_DOY  REPORT_DAY  REPORT_HOUR    OCC_DATE  ...  OCC_HOUR DIVISION  \
# 0           1           1         11.0  2014-01-01  ...      11.0      D13
# 1           1           1         19.0  2014-01-01  ...      19.0      D12
# 2           1           1          8.0  2014-01-01  ...       6.0      NSA
# 3           1           1          NaN  2014-01-01  ...       NaN      D23
# 4           1           1         19.0  2014-01-01  ...      19.0      D42
#
#    PREMISES_TYPE          APPREHENSION_TYPE     SEX  AGE_COHORT HOOD_158  \
# 0          House  Mha Sec 17 (Power Of App)    Male    25 to 34      092
# 1      Apartment  Mha Sec 17 (Power Of App)    Male    18 to 24      115
# 2        Outside  Mha Sec 17 (Power Of App)  Female    55 to 64      NSA
# 3          House  Mha Sec 17 (Power Of App)  Female    45 to 54      007
# 4          House  Mha Sec 17 (Power Of App)    Male    55 to 64      144
#
#                       NEIGHBOURHOOD_158 HOOD_140  \
# 0           Corso Italia-Davenport (92)      092
# 1                    Mount Dennis (115)      115
# 2                                   NSA      NSA
# 3  Willowridge-Martingrove-Richview (7)      007
# 4             Morningside Heights (144)      131
#
#                       NEIGHBOURHOOD_140
# 0           Corso Italia-Davenport (92)
# 1                    Mount Dennis (115)
# 2                                   NSA
# 3  Willowridge-Martingrove-Richview (7)
# 4                           Rouge (131)
#
# [5 rows x 25 columns]

# %%
apprehensions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112314 entries, 0 to 112313
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   _id                112314 non-null  int64
#  1   EVENT_UNIQUE_ID    112314 non-null  object
#  2   REPORT_DATE        112314 non-null  object
#  3   REPORT_YEAR        112314 non-null  int64
#  4   REPORT_MONTH       112314 non-null  object
#  5   REPORT_DOW         112314 non-null  object
#  6   REPORT_DOY         112314 non-null  int64
#  7   REPORT_DAY         112314 non-null  int64
#  8   REPORT_HOUR        108344 non-null  float64
#  9   OCC_DATE           112314 non-null  object
#  10  OCC_YEAR           112314 non-null  int64
#  11  OCC_MONTH          112314 non-null  object
#  12  OCC_DOY            112314 non-null  int64
#  13  OCC_DAY            112314 non-null  int64
#  14  OCC_DOW            112314 non-null  object
#  15  OCC_HOUR           108061 non-null  float64
#  16  DIVISION           112314 non-null  object
#  17  PREMISES_TYPE      112314 non-null  object
#  18  APPREHENSION_TYPE  112314 non-null  object
#  19  SEX                112314 non-null  object
#  20  AGE_COHORT         112314 non-null  object
#  21  HOOD_158           112314 non-null  object
#  22  NEIGHBOURHOOD_158  112314 non-null  object
#  23  HOOD_140           112314 non-null  object
#  24  NEIGHBOURHOOD_140  112314 non-null  object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 21.4+ MB

# %%
apprehensions_df['REPORT_YEAR'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %% [markdown]
# ---
#
# ## Wellbeing Youth: Mental Health

# %%
# Get package metadata using dataset id
package = client.get_package("wellbeing-youth-mental-health")

# %%
# Check resources in package
print(f'Number of resources: {package["num_resources"]}\n')
for idx, resource in enumerate(package["resources"]):
    print(f'''{idx}: {resource["name"]}
    datastore_active: {resource['datastore_active']}
    format: {resource['format']}
    url_type: {resource['url_type']}
    is_datastore_cache_file: {resource['is_datastore_cache_file']}
''')
# Out:
# Number of resources: 13
#
# 0: Mental Health
#     datastore_active: True
#     format: GeoJSON
#     url_type: datastore
#     is_datastore_cache_file: False
#
# 1: Mental Health - 4326.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#     is_datastore_cache_file: True
#
# 2: Mental Health - 2945.gpkg
#     datastore_active: False
#     format: GPKG
#     url_type: upload
#     is_datastore_cache_file: True
#
# 3: Mental Health - 4326.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#     is_datastore_cache_file: True
#
# 4: Mental Health - 2945.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#     is_datastore_cache_file: True
#
# 5: Mental Health - 4326.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#     is_datastore_cache_file: True
#
# 6: Mental Health - 2945.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#     is_datastore_cache_file: True
#
# 7: Mental Health - 4326.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#     is_datastore_cache_file: True
#
# 8: Mental Health - 2945.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#     is_datastore_cache_file: True
#
# 9: Mental Health - 2952.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#     is_datastore_cache_file: True
#
# 10: Mental Health - 2952.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#     is_datastore_cache_file: True
#
# 11: Mental Health - 2952.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#     is_datastore_cache_file: True
#
# 12: Mental Health - 2952.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#     is_datastore_cache_file: True

# %%
# Get resource data:
for resource in package["resources"]:
    # from datastore:
    if resource["datastore_active"]:
        print('fetching data')
        mh_df = pd.read_csv(resource["url"])
# Out:
# fetching data

# %%
mh_df
# Out:
#     _id  OBJECTID                                        AGENCY_NAME  \
# 0     1      1236                              St Michael's Hospital
# 1     2      1237                              St Michael's Hospital
# 2     3      1238                       WoodGreen Community Services
# 3     4      1239            Bangladeshi Canadian Community Services
# 4     5      1240              Harriet Tubman Community Organization
# ..  ...       ...                                                ...
# 94   95      1233             Centre for Addiction and Mental Health
# 95   96      1234             Centre for Addiction and Mental Health
# 96   97      1235         Vasantham, A Tamil Seniors Wellness Centre
# 97   98      1241                                    Youth Unlimited
# 98   99      1242  WoodGreen Community Services - WoodGreen Commu...
#
#                                  ORGANIZATION_ADDRESS  \
# 0               21 McGill St, Toronto, ON     M5B 1H3
# 1                 30 Bond St, Toronto, ON     M5B 1W8
# 2   815 Danforth Ave, Ste 300, Toronto, ON     M4J...
# 3          2899 Danforth Ave, Toronto, ON     M4C 1M3
# 4   1761 Sheppard Ave E, Main Fl, Street Level, To...
# ..                                                ...
# 94  Intergenerational Wellness Centre, 80 Workman ...
# 95  Intergenerational Wellness Centre, 80 Workman ...
# 96  Easttown Centre Plaza, 2660 Eglinton Ave E, To...
# 97              57 Mobile Dr, Toronto, ON     M4A 1H5
# 98  250 Dundas St W, Ste 305, Toronto, ON     M4J 1L2
#
#                    NEIGHBOURHOOD  \
# 0      Church-Yonge Corridor, 75
# 1      Church-Yonge Corridor, 75
# 2   Danforth Village-Toronto, 66
# 3          East End-Danforth, 62
# 4                 Henry Farm, 53
# ..                           ...
# 94                   Niagara, 82
# 95                   Niagara, 82
# 96            Eglinton East, 138
# 97          Victoria Village, 43
# 98                           NaN
#
#                                          OFFICE_PHONE  \
# 0                         Central Intake 416-864-5120
# 1   Office 416-864-5346 ; Emergency Department 416...
# 2                          416-645-6000 ext 2100/2200
# 3                                        416-699-4484
# 4                                        416-496-2042
# ..                                                ...
# 94  Geriatric Central Intake and Referral 416-535-...
# 95                              416-535-8501 ext 4366
# 96                                       416-847-4172
# 97                                       416-383-1477
# 98                                       416-640-1459
#
#                               EMAIL  \
# 0                      steps@smh.ca
# 1                               NaN
# 2        newcomerinfo@woodgreen.org
# 3             nakter@bangladeshi.ca
# 4          info@tubmancommunity.org
# ..                              ...
# 94                              NaN
# 95                              NaN
# 96       vasantham@sherbourne.on.ca
# 97         yu@youthunlimitedgta.com
# 98  ccwscentralintake@woodgreen.org
#
#                                               WEBSITE  \
# 0   <a href="http://www.stmichaelshospital.com/pro...
# 1   <a href="http://www.stmichaelshospital.com" ta...
# 2   <a href="http://www.woodgreen.org" target="_bl...
# 3   <a href="http://www.bangladeshi.ca" target="_b...
# 4   <a href="http://www.tubmancommunity.org" targe...
# ..                                                ...
# 94  <a href="http://www.camh.ca" target="_blank">w...
# 95  <a href="http://www.camh.ca" target="_blank">w...
# 96             <a href="http://" target="_blank"></a>
# 97  <a href="http://www.youthunlimitedgta.ca" targ...
# 98  <a href="http://www.woodgreen.org" target="_bl...
#
#                                           ELIGIBILITY  \
# 0   Youth 16-23 years experiencing a first episode...
# 1   People who need medical care for serious illne...
# 2   Newcomers (immigrants and refugees) * Mentorsh...
# 3   Open to all including immigrants and refugees ...
# 4   Focus on African-Canadian children, youth and ...
# ..                                                ...
# 94  Adults 65 years and older with mental health a...
# 95  Most programs -- children and youth up to 17 y...
# 96                         Tamil speakers of all ages
# 97                          At risk youth 10-21 years
# 98                          Adults 55 years and older
#
#                                   DESCRIPTION_SERVICE  ...  \
# 0   Assessment * treatment * support with school, ...  ...
# 1   Psychiatric emergencies -- Monday-Sunday 24 ho...  ...
# 2   <b>Settlement services</b> -- orientation, int...  ...
# 3   Settlement services * information and referral...  ...
# 4   Social and recreational programs * leadership ...  ...
# ..                                                ...  ...
# 94  Assessment, treatment, consultation, and commu...  ...
# 95  Assessments, treatment and referrals * treatme...  ...
# 96  Health and mental health information, educatio...  ...
# 97  Christian perspective, non-denominational * co...  ...
# 98  Over the phone emotional support and short-ter...  ...
#
#            DATE_UPDATED ADDRESS_POINT_ID   X   Y LONGITUDE LATITUDE  \
# 0   2013-10-21T04:00:00           840654 NaN NaN       NaN      NaN
# 1   2013-10-16T04:00:00           773891 NaN NaN       NaN      NaN
# 2   2016-01-25T05:00:00          7569237 NaN NaN       NaN      NaN
# 3   2015-09-15T04:00:00           790475 NaN NaN       NaN      NaN
# 4   2015-07-15T04:00:00         30013252 NaN NaN       NaN      NaN
# ..                  ...              ...  ..  ..       ...      ...
# 94  2013-02-07T05:00:00         30024232 NaN NaN       NaN      NaN
# 95  2013-02-06T05:00:00         30024232 NaN NaN       NaN      NaN
# 96  2015-02-12T05:00:00         30017495 NaN NaN       NaN      NaN
# 97  2015-01-19T05:00:00          8211544 NaN NaN       NaN      NaN
# 98  2015-10-28T04:00:00           796535 NaN NaN       NaN      NaN
#
#            ADDRESS_FULL    MUNICIPALITY  POSTAL_CODE  \
# 0          21 McGill St  former Toronto      M5B 1H3
# 1            30 Bond St  former Toronto      M5B 1W8
# 2      815 Danforth Ave  former Toronto      M4J 1L2
# 3     2899 Danforth Ave  former Toronto      M4C 1M3
# 4   1761 Sheppard Ave E      North York      M2J 0A5
# ..                  ...             ...          ...
# 94       80 Workman Way  former Toronto      M6J 1H4
# 95       80 Workman Way  former Toronto      M6J 1H4
# 96  2660 Eglinton Ave E     Scarborough      M1K 2S3
# 97         57 Mobile Dr      North York      M4A 1H5
# 98      250 Dundas St W  former Toronto      M5T 2Z5
#
#                                              geometry
# 0   {"type": "Point", "coordinates": [-79.38137399...
# 1   {"type": "Point", "coordinates": [-79.37767928...
# 2   {"type": "Point", "coordinates": [-79.34097126...
# 3   {"type": "Point", "coordinates": [-79.29397796...
# 4   {"type": "Point", "coordinates": [-79.34303694...
# ..                                                ...
# 94  {"type": "Point", "coordinates": [-79.41743080...
# 95  {"type": "Point", "coordinates": [-79.41743080...
# 96  {"type": "Point", "coordinates": [-79.25149414...
# 97  {"type": "Point", "coordinates": [-79.31903689...
# 98  {"type": "Point", "coordinates": [-79.38979490...
#
# [99 rows x 25 columns]

# %% [markdown]
# ---
#
# ## Wellbeing Youth: Concurrent Disorder Programs

# %%
# Get package metadata using dataset id
package = client.get_package("wellbeing-youth-concurrent-disorder-programs")

# %%
# Check resources in package
print(f'Number of resources: {package["num_resources"]}\n')
for idx, resource in enumerate(package["resources"]):
    print(f'''{idx}: {resource["name"]}
    datastore_active: {resource['datastore_active']}
    format: {resource['format']}
    url_type: {resource['url_type']}
    is_datastore_cache_file: {resource['is_datastore_cache_file']}
''')
# Out:
# Number of resources: 13
#
# 0: Concurrent Disorder Programs
#     datastore_active: True
#     format: GeoJSON
#     url_type: datastore
#     is_datastore_cache_file: False
#
# 1: Concurrent Disorder Programs - 4326.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#     is_datastore_cache_file: True
#
# 2: Concurrent Disorder Programs - 2945.gpkg
#     datastore_active: False
#     format: GPKG
#     url_type: upload
#     is_datastore_cache_file: True
#
# 3: Concurrent Disorder Programs - 4326.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#     is_datastore_cache_file: True
#
# 4: Concurrent Disorder Programs - 2945.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#     is_datastore_cache_file: True
#
# 5: Concurrent Disorder Programs - 4326.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#     is_datastore_cache_file: True
#
# 6: Concurrent Disorder Programs - 2945.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#     is_datastore_cache_file: True
#
# 7: Concurrent Disorder Programs - 4326.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#     is_datastore_cache_file: True
#
# 8: Concurrent Disorder Programs - 2945.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#     is_datastore_cache_file: True
#
# 9: Concurrent Disorder Programs - 2952.gpkg
#     datastore_active: False
#     format: gpkg
#     url_type: upload
#     is_datastore_cache_file: True
#
# 10: Concurrent Disorder Programs - 2952.csv
#     datastore_active: False
#     format: CSV
#     url_type: upload
#     is_datastore_cache_file: True
#
# 11: Concurrent Disorder Programs - 2952.zip
#     datastore_active: False
#     format: SHP
#     url_type: upload
#     is_datastore_cache_file: True
#
# 12: Concurrent Disorder Programs - 2952.geojson
#     datastore_active: False
#     format: GeoJSON
#     url_type: upload
#     is_datastore_cache_file: True

# %%
# Get resource data:
for resource in package["resources"]:
    # from datastore:
    if resource["datastore_active"]:
        print('fetching data')
        cdp_df = pd.read_csv(resource["url"])
# Out:
# fetching data

# %%
cdp_df
# Out:
#     _id  OBJECTID                                        AGENCY_NAME  \
# 0     1      1243             Accommodation, Information and Support
# 1     2      1244                           Bellwood Health Services
# 2     3      1245                              Humber River Hospital
# 3     4      1246                                  Jean Tweed Centre
# 4     5      1247  University Health Network, Toronto Western Hos...
# 5     6      1248                       Turning Point Youth Services
# 6     7      1249                       Breakaway Addiction Services
# 7     8      1250                                     Nazareth House
# 8     9      1251                                     Progress Place
# 9    10      1252                                     Salvation Army
# 10   11      1253                                     Salvation Army
# 11   12      1254                                     Griffin Centre
# 12   13      1255             Centre for Addiction and Mental Health
# 13   14      1256             Centre for Addiction and Mental Health
# 14   15      1257             Centre for Addiction and Mental Health
# 15   16      1258                     Good Shepherd Non Profit Homes
# 16   17      1259             Centre for Addiction and Mental Health
# 17   18      1260             Centre for Addiction and Mental Health
# 18   19      1261                                        Fred Victor
# 19   20      1262                    416 Community Support for Women
# 20   21      1263                       WoodGreen Community Services
# 21   22      1264                     Street Haven at the Crossroads
# 22   23      1265             Centre for Addiction and Mental Health
# 23   24      1266             Centre for Addiction and Mental Health
# 24   25      1267         Vasantham, A Tamil Seniors Wellness Centre
# 25   26      1268                       WoodGreen Community Services
#
#                                  ORGANIZATION_ADDRESS  \
# 0   720 Spadina Ave, Ste 316, Toronto, ON     M5S 2T9
# 1          1020 McNicoll Ave, Toronto, ON     M1W 2J6
# 2            1235 Wilson Ave, Toronto, ON     M3M 0B2
# 3              215 Evans Ave, Toronto, ON     M8Z 1J5
# 4   399 Bathurst St, East Wing, 9th Fl, Toronto, O...
# 5          95 Wellesley St E, Toronto, ON     M4Y 2X9
# 6          21 Strickland Ave, Toronto, ON     M6K 3E6
# 7        455 Palmerston Blvd, Toronto, ON     M6G 2N9
# 8              576 Church St, Toronto, ON     M4Y 2E3
# 9   Titan Islington Plaza, 1020 Islington Ave, Uni...
# 10             160 Jarvis St, Toronto, ON     M5B 2E1
# 11  1124 Finch Ave W, Unit 1, Toronto, ON     M3J 2E2
# 12  60 White Squirrel Way, 2nd Fl, Toronto, ON    ...
# 13  Bell Gateway Building, 100 Stokes St, Toronto ...
# 14  The Carlos Fidani Family Building, 60 White Sq...
# 15   550 Queen St E, Ste 315, Toronto, ON     M5A 1V2
# 16  The Carlos Fidani Family Building, 60 White Sq...
# 17  The Carlos Fidani Family Building, 60 White Sq...
# 18            145 Queen St E, Toronto, ON     M5A 1S1
# 19  170 Bloor St W, Ste 1106, Toronto, ON     M5S 1T9
# 20            650 Queen St E, Toronto, ON     M4M 1G5
# 21            87 Pembroke St, Toronto, ON     M5A 2N9
# 22  The Carlos Fidani Family Building, 60 White Sq...
# 23            250 College St, Toronto, ON     M5T 1R8
# 24  Easttown Centre Plaza, 2660 Eglinton Ave E, To...
# 25          815 Danforth Ave, Toronto, ON     M4J 1L2
#
#                      NEIGHBOURHOOD  \
# 0                   University, 79
# 1                     Steeles, 116
# 2         Downsview-Roding-CFB, 26
# 3                       Mimico, 17
# 4            Trinity-Bellwoods, 81
# 5        Church-Yonge Corridor, 75
# 6                 Roncesvalles, 86
# 7      Palmerston-Little Italy, 80
# 8        Church-Yonge Corridor, 75
# 9   Islington-City Centre West, 14
# 10       Church-Yonge Corridor, 75
# 11     York University Heights, 27
# 12                     Niagara, 82
# 13                     Niagara, 82
# 14                     Niagara, 82
# 15                 Regent Park, 72
# 16                     Niagara, 82
# 17                     Niagara, 82
# 18                   Moss Park, 73
# 19                       Annex, 95
# 20             South Riverdale, 70
# 21                   Moss Park, 73
# 22                     Niagara, 82
# 23        Kensington-Chinatown, 78
# 24              Eglinton East, 138
# 25    Danforth Village-Toronto, 66
#
#                                          OFFICE_PHONE  \
# 0                                        416-504-3610
# 1                                        416-495-0926
# 2                                        416-242-1000
# 3                                        416-255-7359
# 4                                        416-603-5974
# 5                                        416-925-9250
# 6                                        416-234-1942
# 7                                        416-532-0336
# 8                                        416-323-0223
# 9                                        416-255-7070
# 10                                       416-363-5496
# 11                                       416-222-1153
# 12  Access CAMH (Intake Assessment) 416-535-8501 e...
# 13                     Access CAMH 416-535-8501 ext 2
# 14  Access CAMH (Intake Assessment) 416-535-8501 e...
# 15                                       416-203-2711
# 16                      Intake 416-535-8501 ext 33985
# 17  Access CAMH (Intake Assessment) 416-535-8501 e...
# 18                                       416-369-1199
# 19                                       416-964-6936
# 20                              416-645-6000 ext 2529
# 21                                       416-967-0133
# 22  Access CAMH (Intake Assessment) 416-535-8501 e...
# 23              416-979-6885 ; 416-535-8501 ext 36885
# 24                                       416-847-4172
# 25                                       416-645-6000
#
#                                  EMAIL  \
# 0              mbastidas@aistoronto.ca
# 1                     info@bellwood.ca
# 2                                  NaN
# 3                   info@jeantweed.com
# 4                                  NaN
# 5                 info@turningpoint.ca
# 6     breakaway@breakawayaddictions.ca
# 7          nazareth_house@sympatico.ca
# 8            theclub@progressplace.org
# 9                     info@tsa-bss.org
# 10  karen_french@can.salvationarmy.org
# 11           contact@griffincentre.org
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19             alex.b@416community.com
# 20           housinghelp@woodgreen.org
# 21                info@streethaven.com
# 22                                 NaN
# 23                                 NaN
# 24          vasantham@sherbourne.on.ca
# 25                                 NaN
#
#                                               WEBSITE  \
# 0   <a href="http://www.aistoronto.ca" target="_bl...
# 1   <a href="http://www.bellwood.ca" target="_blan...
# 2   <a href="http://www.hrh.ca" target="_blank">ww...
# 3   <a href="http://www.jeantweed.com" target="_bl...
# 4   <a href="http://www.uhn.ca" target="_blank">ww...
# 5   <a href="http://www.turningpoint.ca" target="_...
# 6   <a href="http://www.breakawayaddictions.ca" ta...
# 7   <a href="http://www.nazarethhouse.ca" target="...
# 8   <a href="http://www.progressplace.org" target=...
# 9   <a href="http://www.tsa-bss.org" target="_blan...
# 10  <a href="http://www.torontoharbourlight.ca" ta...
# 11  <a href="http://www.griffincentre.org" target=...
# 12  <a href="http://www.camh.ca" target="_blank">w...
# 13  <a href="http://www.camh.ca" target="_blank">w...
# 14  <a href="http://www.camh.ca" target="_blank">w...
# 15  <a href="http://www.goodshepherdcentres.ca" ta...
# 16  <a href="http://www.camh.ca" target="_blank">w...
# 17  <a href="http://www.camh.ca" target="_blank">w...
# 18  <a href="http://www.fredvictor.org" target="_b...
# 19  <a href="http://www.416community.com" target="...
# 20  <a href="http://www.woodgreen.org" target="_bl...
# 21  <a href="http://www.streethaven.com" target="_...
# 22  <a href="http://www.camh.ca" target="_blank">w...
# 23  <a href="http://www.camh.ca" target="_blank">w...
# 24             <a href="http://" target="_blank"></a>
# 25  <a href="http://www.woodgreen.org" target="_bl...
#
#                                           ELIGIBILITY  \
# 0   Individuals 16 years and older, single or with...
# 1   Women and men 19 years and older, with alcohol...
# 2                                                 NaN
# 3   Women 16 years and older who have problems wit...
# 4   Portuguese speaking people with a mental healt...
# 5   Residential treatment, mental health counselli...
# 6           Varies for individual programs, see below
# 7   Women 18-50 years, at risk of homelessness and...
# 8   Adults 18-65 years with significant mental hea...
# 9   Adults 18 years and older with a mental health...
# 10  Residential program -- men 18 years and older ...
# 11  Youth and young adults 15-25 years with addict...
# 12  Individuals with addiction and persistent ment...
# 13  Women and men with an eating disorder or food ...
# 14  Lesbian, gay, bisexual, transgender, transsexu...
# 15  Single men and women 18-65 years who experienc...
# 16  Aboriginal individuals 16 years and older, who...
# 17  Women 18 years and older with moderate to seve...
# 18  Housing -- single adults 16 years and older wh...
# 19  Women 16 years and older dealing with both add...
# 20                                    No restrictions
# 21  Women 16 years and older with substance use is...
# 22  Adults 18 years and older with moderate to sev...
# 23  Individuals 16 years and older, with mental he...
# 24                         Tamil speakers of all ages
# 25  Persons who are socially isolated * persons wh...
#
#                                   DESCRIPTION_SERVICE  ...  \
# 0   Permanent supportive housing * bachelor, one a...  ...
# 1   Residential and outpatient addiction treatment...  ...
# 2   Acute care hospital * medical and surgical inp...  ...
# 3   Intensive 3 week residential and day treatment...  ...
# 4   Linguistically and culturally appropriate ment...  ...
# 5   Residential and nonresidential programs * stru...  ...
# 6   Comprehensive, community-based, individualized...  ...
# 7   Supportive transition house * capacity 11, inc...  ...
# 8   Community-based psychosocial rehabilitation ce...  ...
# 9   Outreach agency * wrap around treatment servic...  ...
# 10  <b>Residential Treatment Program</b> -- up to ...  ...
# 11  Mental health and substance use services for t...  ...
# 12  Outpatient program -- psychiatric assessment a...  ...
# 13  Outpatient program includes integrated concurr...  ...
# 14  Assessment and referrals * confidential counse...  ...
# 15  Supportive housing in Toronto and Hamilton\n<b...  ...
# 16  Assessment and referrals * individual, couple ...  ...
# 17  Addiction and concurrent disorder treatment se...  ...
# 18  Services include information and referral, hou...  ...
# 19  Individual and group counselling * assistance ...  ...
# 20  <b>Housing Help Centre (InfoLink) </b> -- one-...  ...
# 21  Addiction counselling in the community -- indi...  ...
# 22  Inpatient treatment program -- capacity 30 * g...  ...
# 23  Emergency department including observation, as...  ...
# 24  Health and mental health information, educatio...  ...
# 25  Concurrent Disorder and Harm Reduction Service...  ...
#
#            DATE_UPDATED ADDRESS_POINT_ID   X   Y LONGITUDE LATITUDE  \
# 0   2015-05-07T04:00:00           870176 NaN NaN       NaN      NaN
# 1   2014-10-15T04:00:00          9311782 NaN NaN       NaN      NaN
# 2   2015-10-16T04:00:00         30063647 NaN NaN       NaN      NaN
# 3   2016-01-07T05:00:00         10998869 NaN NaN       NaN      NaN
# 4   2014-01-31T05:00:00          9086232 NaN NaN       NaN      NaN
# 5   2015-05-05T04:00:00         13967932 NaN NaN       NaN      NaN
# 6   2015-02-05T05:00:00          3959847 NaN NaN       NaN      NaN
# 7   2015-01-12T05:00:00          2854195 NaN NaN       NaN      NaN
# 8   2015-08-05T04:00:00          7731590 NaN NaN       NaN      NaN
# 9   2015-08-05T04:00:00          7668065 NaN NaN       NaN      NaN
# 10  2015-02-03T05:00:00          8771552 NaN NaN       NaN      NaN
# 11  2015-09-16T04:00:00          9171888 NaN NaN       NaN      NaN
# 12  2015-02-25T05:00:00         20232089 NaN NaN       NaN      NaN
# 13  2015-02-25T05:00:00         30024467 NaN NaN       NaN      NaN
# 14  2015-02-25T05:00:00         20232089 NaN NaN       NaN      NaN
# 15  2015-06-10T04:00:00          8754194 NaN NaN       NaN      NaN
# 16  2015-04-16T04:00:00         20232089 NaN NaN       NaN      NaN
# 17  2015-04-20T04:00:00         20232089 NaN NaN       NaN      NaN
# 18  2015-04-07T04:00:00          6624470 NaN NaN       NaN      NaN
# 19  2015-10-29T04:00:00         14012281 NaN NaN       NaN      NaN
# 20  2016-02-22T05:00:00          8292595 NaN NaN       NaN      NaN
# 21  2015-06-08T04:00:00          2591634 NaN NaN       NaN      NaN
# 22  2015-02-26T05:00:00         20232089 NaN NaN       NaN      NaN
# 23  2015-04-16T04:00:00          9942219 NaN NaN       NaN      NaN
# 24  2015-02-12T05:00:00         30017495 NaN NaN       NaN      NaN
# 25  2015-09-18T04:00:00          7569237 NaN NaN       NaN      NaN
#
#              ADDRESS_FULL    MUNICIPALITY  POSTAL_CODE  \
# 0         720 Spadina Ave  former Toronto      M5S 2T9
# 1       1020 McNicoll Ave     Scarborough      M1W 2J6
# 2         1235 Wilson Ave      North York      M3M 0B2
# 3           215 Evans Ave       Etobicoke      M8Z 1J5
# 4         399 Bathurst St  former Toronto      M5T 2S8
# 5       95 Wellesley St E  former Toronto      M4Y 2X9
# 6       21 Strickland Ave  former Toronto      M6K 3E6
# 7     455 Palmerston Blvd  former Toronto      M6G 2N9
# 8           576 Church St  former Toronto      M4Y 2E3
# 9      1020 Islington Ave       Etobicoke      M8Z 6A4
# 10          160 Jarvis St  former Toronto      M5B 2E1
# 11       1124 Finch Ave W      North York      M3J 2E2
# 12  60 White Squirrel Way  former Toronto      M6J 1H4
# 13          100 Stokes St  former Toronto      M6J 1H4
# 14  60 White Squirrel Way  former Toronto      M6J 1H4
# 15         550 Queen St E  former Toronto      M5A 1V2
# 16  60 White Squirrel Way  former Toronto      M6J 1H4
# 17  60 White Squirrel Way  former Toronto      M6J 1H4
# 18         145 Queen St E  former Toronto      M5A 1S1
# 19         170 Bloor St W  former Toronto      M5S 1T9
# 20         650 Queen St E  former Toronto      M4M 1G5
# 21         87 Pembroke St  former Toronto      M5A 2N9
# 22  60 White Squirrel Way  former Toronto      M6J 1H4
# 23         250 College St  former Toronto      M5T 1R8
# 24    2660 Eglinton Ave E     Scarborough      M1K 2S3
# 25       815 Danforth Ave  former Toronto      M4J 1L2
#
#                                              geometry
# 0   {"type": "Point", "coordinates": [-79.40361735...
# 1   {"type": "Point", "coordinates": [-79.33600977...
# 2   {"type": "Point", "coordinates": [-79.48921562...
# 3   {"type": "Point", "coordinates": [-79.51552302...
# 4   {"type": "Point", "coordinates": [-79.40568847...
# 5   {"type": "Point", "coordinates": [-79.37921199...
# 6   {"type": "Point", "coordinates": [-79.43103838...
# 7   {"type": "Point", "coordinates": [-79.41198288...
# 8   {"type": "Point", "coordinates": [-79.38159464...
# 9   {"type": "Point", "coordinates": [-79.51848970...
# 10  {"type": "Point", "coordinates": [-79.37417698...
# 11  {"type": "Point", "coordinates": [-79.47626193...
# 12  {"type": "Point", "coordinates": [-79.42117046...
# 13  {"type": "Point", "coordinates": [-79.41922349...
# 14  {"type": "Point", "coordinates": [-79.42117046...
# 15  {"type": "Point", "coordinates": [-79.35723749...
# 16  {"type": "Point", "coordinates": [-79.42117046...
# 17  {"type": "Point", "coordinates": [-79.42117046...
# 18  {"type": "Point", "coordinates": [-79.37296906...
# 19  {"type": "Point", "coordinates": [-79.39452262...
# 20  {"type": "Point", "coordinates": [-79.35204196...
# 21  {"type": "Point", "coordinates": [-79.37242635...
# 22  {"type": "Point", "coordinates": [-79.42117046...
# 23  {"type": "Point", "coordinates": [-79.39911442...
# 24  {"type": "Point", "coordinates": [-79.25149414...
# 25  {"type": "Point", "coordinates": [-79.34097126...
#
# [26 rows x 25 columns]
